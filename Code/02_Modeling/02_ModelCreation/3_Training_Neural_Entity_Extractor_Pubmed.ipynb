# %% [markdown]
# ## Training a Neural Entity Extractor using PubMed Word Embeddings

# %% [markdown]
# ### Step 1

# %% [markdown]
# #### Copy the Embeddings from source location to destination location <br>

# %%
# From Azure ML CLI
# (1) upgrade tensorflow to the GPU version
# !conda install tensorflow-gpu
# (2) install fastparquet
# !conda install fastparquet

# %%
import tensorflow
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
tensorflow.device('/gpu:0')
# Out:
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14594599266161431555
# , name: "/gpu:0"
# device_type: "GPU"
# memory_limit: 174063616
# locality {
#   bus_id: 1
# }
# incarnation: 14645120121624889074
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 1852:00:00.0"
# ]

# %% [markdown]
# #### Generate the Embedding Matrix from parquet files on the Container linked to your Spark Cluster

# %%
#Generate the Embedding Matrix by reading the TSV files
from azure.storage.blob import BlockBlobService
import numpy as np
import datetime

import os
import shutil
import fastparquet
import pickle
import os 

window_size = 5
vector_size = 50
min_count =400

home_dir = "C:\dl4nlp"
print("home_dir = {}".format(home_dir))

#Specify the string to look for in blob names from your container
embedding_relative_path = "Models/word2vec_pubmed_model_vs_{}_ws_{}_mc_{}_parquet_files".\
    format(vector_size, window_size, min_count)
        
data_folder = "Data/Drugs_and_Diseases/"
train_file_path = os.path.join(data_folder, "train_out.txt")
test_file_path = os.path.join(data_folder, "test.txt")

#Azure BLOB Storage account information
storage_account_name = '76f8577bf451dsvm'
storage_account_key ='5DPDh+p3Xbg9BfS9d/OSrtQ/Utrat1Rr/NRrGU+x3cRYPZYi6B92WEWUIkM28Z8cGRsRz0cuSGb2mjyBCB0QXg=='
storage_container_name ='dl4nlp-container'
timestart = datetime.datetime.now()

block_blob_service = BlockBlobService(account_name = storage_account_name, account_key = storage_account_key)

#Specify the path where to store the downloaded files

embedding_full_path = os.path.join(home_dir, embedding_relative_path)
print("embedding_full_path= {}".format(embedding_full_path))

if os.path.exists(embedding_full_path):
    shutil.rmtree(embedding_full_path)

os.makedirs(embedding_full_path)
        
num_parquet_files = 0
generator = block_blob_service.list_blobs(storage_container_name)
for blob in generator:      
    if embedding_relative_path in blob.name and blob.name.endswith(".parquet"):              
        num_parquet_files = num_parquet_files +1
        filename = blob.name.split("/")[-1]
        block_blob_service.get_blob_to_path(storage_container_name, blob.name, os.path.join(embedding_full_path,filename))      
        
print ("Reading {} parquet files".format(num_parquet_files))
timeend = datetime.datetime.now()
timedelta = round((timeend-timestart).total_seconds() / 60, 2)
print ("Time taken to execute above cell: " + str(timedelta) + " mins")
# Out:
# home_dir = C:\dl4nlp
# embedding_full_path= C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files
# Reading 1000 parquet files
# Time taken to execute above cell: 1.48 mins

# %% [markdown]
# Save the embedding matrix into a pickle file

# %%
import pandas 
import datetime
timestart = datetime.datetime.now()

print ("Embedding vector size =", vector_size)

embedding_pickle_file = os.path.join(home_dir, "Models/w2vmodel_pubmed_vs_{}_ws_{}_mc_{}.pkl" \
 .format(vector_size, window_size, min_count))

Word2Vec_Model = {}

print("Reading the Parquet embedding files ....")
files = os.listdir(embedding_full_path)
for index, filename in enumerate(files):
    if "part" in filename:        
        parquet_file_path = os.path.join(embedding_full_path,filename)
        print("reading {}".format(parquet_file_path))

        try:
            pfile = fastparquet.ParquetFile(parquet_file_path) 
            # convert to pandas dataframe
            df =  pfile.to_pandas()    
#             df = pandas.read_csv(tsv_full_path, sep='\t')
        
            #print(df.head())    
            arr = list(df.values)                 
            for ind, vals in enumerate(arr):
                word = vals[0]
                word_vec = vals[-vector_size:]
                word_vec = np.array(word_vec)
                Word2Vec_Model[word] = word_vec.astype('float32')
        except:
            print("Skip {}".format(filename))
            
#save the embedding matrix into a pickle file
print("save the embedding matrix of {} entries into a pickle file".format(len(Word2Vec_Model)))
pickle.dump(Word2Vec_Model, open(embedding_pickle_file, "wb")) 
    
timeend = datetime.datetime.now()
timedelta = round((timeend-timestart).total_seconds() / 60, 2)
print ("Time taken to execute above cell: " + str(timedelta) + " mins")
# Out:
# Embedding vector size = 50
# Reading the Parquet embedding files ....
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00000-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00001-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00002-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00003-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00004-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00005-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00006-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00007-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00008-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00009-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00010-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00011-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00012-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00013-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00014-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00015-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00016-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00017-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00018-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00019-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00020-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00021-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00022-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00023-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00024-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00025-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00026-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00027-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00028-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00029-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00030-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00031-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00032-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00033-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00034-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00035-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00036-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00037-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00038-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00039-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00040-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00041-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00042-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00043-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00044-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00045-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00046-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00047-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00048-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00049-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00050-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00051-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00052-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00053-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00054-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00055-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00056-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00057-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00058-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00059-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00060-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00061-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00062-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00063-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00064-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00065-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00066-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00067-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00068-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00069-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00070-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00071-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00072-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00073-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00074-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00075-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00076-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00077-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00078-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00079-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00080-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00081-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00082-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00083-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00084-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00085-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00086-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00087-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00088-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00089-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00090-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00091-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00092-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00093-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00094-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00095-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00096-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00097-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00098-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00099-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00100-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00101-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00102-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00103-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00104-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00105-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00106-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00107-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00108-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00109-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00110-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00111-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00112-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00113-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00114-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00115-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00116-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00117-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00118-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00119-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00120-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00121-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00122-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00123-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00124-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00125-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00126-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00127-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00128-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00129-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00130-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00131-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00132-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00133-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00134-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00135-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00136-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00137-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00138-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00139-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00140-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00141-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00142-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00143-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00144-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00145-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00146-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00147-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00148-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00149-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00150-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00151-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00152-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00153-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00154-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00155-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00156-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00157-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00158-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00159-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00160-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00161-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00162-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00163-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00164-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00165-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00166-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00167-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00168-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00169-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00170-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00171-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00172-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00173-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00174-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00175-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00176-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00177-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00178-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00179-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00180-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00181-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00182-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00183-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00184-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00185-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00186-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00187-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00188-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00189-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00190-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00191-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00192-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00193-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00194-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00195-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00196-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00197-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00198-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00199-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00200-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00201-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00202-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00203-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00204-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00205-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00206-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00207-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00208-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00209-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00210-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00211-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00212-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00213-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00214-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00215-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00216-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00217-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00218-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00219-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00220-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00221-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00222-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00223-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00224-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00225-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00226-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00227-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00228-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00229-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00230-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00231-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00232-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00233-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00234-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00235-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00236-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00237-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00238-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00239-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00240-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00241-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00242-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00243-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00244-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00245-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00246-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00247-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00248-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00249-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00250-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00251-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00252-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00253-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00254-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00255-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00256-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00257-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00258-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00259-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00260-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00261-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00262-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00263-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00264-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00265-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00266-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00267-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00268-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00269-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00270-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00271-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00272-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00273-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00274-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00275-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00276-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00277-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00278-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00279-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00280-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00281-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00282-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00283-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00284-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00285-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00286-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00287-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00288-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00289-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00290-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00291-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00292-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00293-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00294-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00295-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00296-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00297-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00298-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00299-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00300-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00301-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00302-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00303-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00304-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00305-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00306-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00307-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00308-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00309-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00310-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00311-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00312-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00313-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00314-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00315-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00316-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00317-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00318-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00319-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00320-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00321-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00322-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00323-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00324-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00325-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00326-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00327-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00328-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00329-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00330-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00331-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00332-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00333-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00334-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00335-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00336-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00337-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00338-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00339-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00340-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00341-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00342-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00343-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00344-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00345-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00346-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# ...
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00885-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00886-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00887-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00888-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00889-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00890-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00891-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00892-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00893-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00894-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00895-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00896-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00897-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00898-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00899-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00900-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00901-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00902-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00903-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00904-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00905-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00906-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00907-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00908-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00909-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00910-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00911-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00912-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00913-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00914-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00915-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00916-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00917-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00918-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00919-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00920-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00921-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00922-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00923-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00924-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00925-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00926-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00927-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00928-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00929-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00930-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00931-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00932-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00933-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00934-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00935-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00936-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00937-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00938-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00939-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00940-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00941-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00942-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00943-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00944-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00945-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00946-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00947-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00948-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00949-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00950-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00951-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00952-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00953-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00954-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00955-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00956-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00957-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00958-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00959-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00960-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00961-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00962-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00963-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00964-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00965-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00966-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00967-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00968-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00969-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00970-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00971-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00972-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00973-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00974-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00975-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00976-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00977-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00978-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00979-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00980-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00981-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00982-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00983-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00984-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00985-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00986-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00987-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00988-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00989-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00990-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00991-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00992-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00993-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00994-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00995-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00996-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00997-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00998-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# reading C:\dl4nlp\Models/word2vec_pubmed_model_vs_50_ws_5_mc_400_parquet_files\part-00999-858f31b5-52a6-49cf-b541-9fc814fb1662.gz.parquet
# save the embedding matrix of 126855 entries into a pickle file
# Time taken to execute above cell: 0.92 mins

# %% [markdown]
# #### Copy the Training Data, Testing Data, Evaluation Script to destination location

# %%
len(Word2Vec_Model)
# Out:
# 126855

# %%
from azure.storage.blob import BlockBlobService
import os
block_blob_service = BlockBlobService(account_name = storage_account_name, account_key = storage_account_key)

generator = block_blob_service.list_blobs(storage_container_name)

if not os.path.exists(os.path.join(home_dir, data_folder)):
    os.makedirs(os.path.join(home_dir, data_folder))
    
local_train_file_path  = os.path.join(home_dir, train_file_path)
local_test_file_path  = os.path.join(home_dir, test_file_path)

block_blob_service.get_blob_to_path(storage_container_name, train_file_path, local_train_file_path)
block_blob_service.get_blob_to_path(storage_container_name, test_file_path, local_test_file_path)

# %% [markdown]
# #### Prepare the Training and Testing Data in the correct format for Keras

# %%
# %%writefile Data_Preparation2.py
from keras.preprocessing import sequence
import numpy as np
#Pytnon 2
#import cPickle as cpickle

#Pytnon 3
import _pickle as cPickle

class DataPreparation:

#     def __init__ (self, num_classes, seq_length, train_file=None, test_file=None, embeddings_file=None, vector_size = 100):
    def __init__ (self, num_classes, seq_length, embeddings_file=None, vector_size = 100):
        # Some constants
        self.DEFAULT_N_CLASSES = num_classes
        self.DEFAULT_N_FEATURES = vector_size
        self.DEFAULT_MAX_SEQ_LENGTH = seq_length
        
        # Other stuff
        self.wordvecs = None
        self.word_to_ix_map = {}
        self.n_features = 0
        self.n_tag_classes = 0
        self.n_sentences_all = 0
        self.tag_vector_map = {}
        
        self.max_sentence_len_train = 0
        self.max_sentence_len_test = 0
        self.max_sentence_len = 0
        
#         self.all_X_train = []
#         self.all_Y_train = []
#         self.all_X_test = []
#         self.all_Y_test = []
        self.unk_words = []
        
        self.load_embedding_lookup_table(embeddings_file)
#         self.read_and_parse_data(train_file, test_file, embeddings_file)
            
#     def get_data (self):
#         return (self.all_X_train, self.all_Y_train, \
#                 self.all_X_test, self.all_Y_test, \
#                 self.wordvecs)
    
    def decode_prediction_sequence (self, pred_seq):
        
        pred_tags = []
        for class_prs in pred_seq:
            class_vec = np.zeros(self.DEFAULT_N_CLASSES, dtype=np.int32)
            class_vec[np.argmax(class_prs)] = 1
            if tuple(class_vec.tolist()) in self.tag_vector_map:
                pred_tags.append(self.tag_vector_map[tuple(class_vec.tolist())])
            else:
                print(tuple(class_vec.tolist()))
        return pred_tags
    
    def load_embedding_lookup_table (self, embeddings_file):
        
        ###Load the Word2Vec Model###
        print("Loading the W2V model from file {}".format(embeddings_file))
        #W2V_model = cPickle.load(open(embeddings_file, "rb"))
        with open(embeddings_file, 'rb') as f:
            W2V_model = cPickle.load(f, encoding='bytes')                     
            
        vocab = list(W2V_model.keys())       
        
        self.word_to_ix_map = {}
        self.wordvecs = []
        
        ###Create LookUp Table for words and their word vectors###
        print("Creating the lookup table")
        for index, word in enumerate(vocab):
            self.word_to_ix_map[word] = index
            self.wordvecs.append(W2V_model[vocab[index]])
            
           
        self.wordvecs = np.array(self.wordvecs)
        print("Number of entries in the lookup table = {}".format(len(self.wordvecs)))
        self.n_features = len(self.wordvecs[0])
        print("embedding size = {}".format(self.n_features))
        
        # Add a zero vector for the Paddings
        self.wordvecs = np.vstack((self.wordvecs, np.zeros(self.DEFAULT_N_FEATURES)))
        zero_vec_pos = self.wordvecs.shape[0] - 1
        
        print("Done")
        return (self.wordvecs)
    
    
    
    ##########################  READ TRAINING DATA  ######################### 
    def read_and_parse_training_data (self, train_file, skip_unknown_words = False):
        
        print("Loading the training data from file {}".format(train_file))
        with open(train_file, 'r') as f_train:
            
            self.n_tag_classes = self.DEFAULT_N_CLASSES
            self.tag_vector_map = {}    # For storing one hot vector notation for each Tag
            tag_class_id = 0            # Used to put 1 in the one hot vector notation
            raw_data_train = []
            raw_words_train = []
            raw_tags_train = []        

            # Process all lines in the file
            for line in f_train:
                line = line.strip()
                if not line:
                    raw_data_train.append( (tuple(raw_words_train), tuple(raw_tags_train)))
                    raw_words_train = []
                    raw_tags_train = []
                    continue
                
                word, tag = line.split('\t')
                
                raw_words_train.append(word)
                raw_tags_train.append(tag)
                
                if tag not in self.tag_vector_map:
                    one_hot_vec = np.zeros(self.DEFAULT_N_CLASSES, dtype=np.int32)
                    one_hot_vec[tag_class_id] = 1
                    self.tag_vector_map[tag] = tuple(one_hot_vec)
                    self.tag_vector_map[tuple(one_hot_vec)] = tag
                    tag_class_id += 1
                    
        print("number of training examples = " + str(len(raw_data_train)))
        
        #Adding a None Tag
        one_hot_vec = np.zeros(self.DEFAULT_N_CLASSES, dtype = np.int32)
        one_hot_vec[tag_class_id] = 1
        self.tag_vector_map['NONE'] = tuple(one_hot_vec)
        self.tag_vector_map[tuple(one_hot_vec)] = 'NONE'
        tag_class_id += 1
        
        self.n_sentences_all = len(raw_data_train)

        # Find the maximum sequence length for Training data
        self.max_sentence_len_train = 0
        for seq in raw_data_train:
            if len(seq[0]) > self.max_sentence_len_train:
                self.max_sentence_len_train = len(seq[0])                
        
         ############## Create Train Vectors################
        all_X_train, all_Y_train = [], []
        
        self.unk_words = []
        count = 0
        for word_seq, tag_seq in raw_data_train:  
            
            elem_wordvecs, elem_tags = [], []            
            for ix in range(len(word_seq)):
                w = word_seq[ix]
                t = tag_seq[ix]
                w = w.lower()
                if w in self.word_to_ix_map :
                    count += 1
                    elem_wordvecs.append(self.word_to_ix_map[w])
                    elem_tags.append(self.tag_vector_map[t])

                elif "UNK" in self.word_to_ix_map :
                    elem_wordvecs.append(self.word_to_ix_map["UNK"])
                    elem_tags.append(self.tag_vector_map[t])
                
                else:
                    w = "UNK"       
                    new_wv = 2 * np.random.randn(self.DEFAULT_N_FEATURES) - 1 # sample from normal distribution
                    norm_const = np.linalg.norm(new_wv)
                    new_wv /= norm_const
                    self.wordvecs = np.vstack((self.wordvecs, new_wv))
                    self.word_to_ix_map[w] = self.wordvecs.shape[0] - 1
                    elem_wordvecs.append(self.word_to_ix_map[w])
                    elem_tags.append(list(self.tag_vector_map[t]))

            
            # Pad the sequences for missing entries to make them all the same length
            nil_X = zero_vec_pos
            nil_Y = np.array(self.tag_vector_map['NONE'])
            pad_length = self.max_sentence_len - len(elem_wordvecs)
            all_X_train.append( ((pad_length)*[nil_X]) + elem_wordvecs)
            all_Y_train.append( ((pad_length)*[nil_Y]) + elem_tags)

        all_X_train = np.array(all_X_train)
        all_Y_train = np.array(all_Y_train)
        
        print("UNK WORD COUNT = " + str(len(self.unk_words)))
        print("Found WORDS COUNT = " + str(count))
        print("TOTAL WORDS = " + str(count+len(self.unk_words)))    
        
        print("Done")
        
        return (all_X_train, all_Y_train)
    
    
    
    ##########################  READ TEST DATA  ######################### 
    def read_and_parse_test_data (self, test_file, skip_unknown_words = False):
        
        print("Loading test data from file {}".format(test_file))
        with open(test_file, 'r') as f_test:
            
            self.n_tag_classes = self.DEFAULT_N_CLASSES
            tag_class_id = 0 
            raw_data_test = []
            raw_words_test = []
            raw_tags_test = []        

            # Process all lines in the file
            for line in f_test:
                line = line.strip()
                if not line:
                    raw_data_test.append( (tuple(raw_words_test), tuple(raw_tags_test)))
                    raw_words_test = []
                    raw_tags_test = []
                    continue
                
                word, tag = line.split('\t') 
                
                if tag not in self.tag_vector_map:
                    print("added")
                    one_hot_vec = np.zeros(self.DEFAULT_N_CLASSES, dtype=np.int32)
                    one_hot_vec[tag_class_id] = 1
                    self.tag_vector_map[tag] = tuple(one_hot_vec)
                    self.tag_vector_map[tuple(one_hot_vec)] = tag
                    tag_class_id += 1
                
                raw_words_test.append(word)
                raw_tags_test.append(tag)                
                                    
        print("number of test examples = " + str(len(raw_data_test)))
        self.n_sentences_all = len(raw_data_test)

#         # Find the maximum sequence length for Test Data
#         self.max_sentence_len_test = 0
#         for seq in raw_data_test:
#             if len(seq[0]) > self.max_sentence_len_test:
#                 self.max_sentence_len_test = len(seq[0])
                
#         #Find the maximum sequence length in both training and Testing dataset
#         self.max_sentence_len = max(self.max_sentence_len_train, self.max_sentence_len_test)               
        
        ########################Create TEST Feature Vectors##########################
        self.all_X_test, self.all_Y_test = [], []
        
        for word_seq, tag_seq in raw_data_test:  
            
            elem_wordvecs, elem_tags = [], []            
            for ix in range(len(word_seq)):
                w = word_seq[ix]
                t = tag_seq[ix]
                w = w.lower()
                if w in self.word_to_ix_map:
                    count += 1
                    elem_wordvecs.append(self.word_to_ix_map[w])
                    elem_tags.append(self.tag_vector_map[t])
                    
                elif "UNK" in self.word_to_ix_map :
                    self.unk_words.append(w)
                    elem_wordvecs.append(self.word_to_ix_map["UNK"])
                    elem_tags.append(self.tag_vector_map[t])
                    
                else:
                    self.unk_words.append(w)
                    w = "UNK"
                    self.word_to_ix_map[w] = self.wordvecs.shape[0] - 1
                    elem_wordvecs.append(self.word_to_ix_map[w])
                    elem_tags.append(self.tag_vector_map[t])
                
            # Pad the sequences for missing entries to make them all the same length
            nil_X = zero_vec_pos
            nil_Y = np.array(self.tag_vector_map['NONE'])
            pad_length = self.max_sentence_len - len(elem_wordvecs)
            all_X_test.append( ((pad_length)*[nil_X]) + elem_wordvecs)
            all_Y_test.append( ((pad_length)*[nil_Y]) + elem_tags)

        all_X_test = np.array(all_X_test)
        all_Y_test = np.array(all_Y_test)
        
        print("UNK WORD COUNT = " + str(len(self.unk_words)))
        print("Found WORDS COUNT = " + str(count))
        print("TOTAL WORDS = " + str(count+len(self.unk_words)))         
        
        print("Done")
        
        return (all_X_test, all_Y_test)
                                         
        
        
    ##########################  READ UNLABELED DATA  ######################### 
    def read_and_parse_unlabeled_data (self, data_file, skip_unknown_words = False):
        
        print("Loading unlabeled data from file {}".format(data_file))
        with open(data_file, 'r') as f_data:
            
            self.n_tag_classes = self.DEFAULT_N_CLASSES
            tag_class_id = 0 
            raw_data_test = []
            raw_words_test = []
#             raw_tags_test = []        

            # Process all lines in the file
            for line in f_data:
                line = line.strip()
                if not line:
                    #flush
                    raw_data_test.append( tuple(raw_words_test) )
                    raw_words_test = []
#                     raw_tags_test = []
                    continue
                
#                 word, tag = line.split('\t') 
                word = line
                
#                 if tag not in self.tag_vector_map:
#                     print("added")
#                     one_hot_vec = np.zeros(self.DEFAULT_N_CLASSES, dtype=np.int32)
#                     one_hot_vec[tag_class_id] = 1
#                     self.tag_vector_map[tag] = tuple(one_hot_vec)
#                     self.tag_vector_map[tuple(one_hot_vec)] = tag
#                     tag_class_id += 1
                
                raw_words_test.append(word)
#                 raw_tags_test.append(tag)                
                                    
        print("number of unlabeled examples = " + str(len(raw_data_test)))
        self.n_sentences_all = len(raw_data_test)

#         # Find the maximum sequence length for Test Data
#         self.max_sentence_len_test = 0
#         for seq in raw_data_test:
#             if len(seq[0]) > self.max_sentence_len_test:
#                 self.max_sentence_len_test = len(seq[0])
                
#         #Find the maximum sequence length in both training and Testing dataset
#         self.max_sentence_len = max(self.max_sentence_len_train, self.max_sentence_len_test)               
        
        ########################Create UNLABELED DATA Feature Vectors##########################
        all_X_data = []
        
        for word_seq in raw_data_test:  
            
            elem_wordvecs = []            
            for ix in range(len(word_seq)):
                w = word_seq[ix]
                
                w = w.lower()
                if w in self.word_to_ix_map:
                    count += 1
                    elem_wordvecs.append(self.word_to_ix_map[w])                
                    
                elif "UNK" in self.word_to_ix_map :
                    self.unk_words.append(w)
                    elem_wordvecs.append(self.word_to_ix_map["UNK"])                    
                    
                else:
                    self.unk_words.append(w)
                    w = "UNK"
                    self.word_to_ix_map[w] = self.wordvecs.shape[0] - 1
                    elem_wordvecs.append(self.word_to_ix_map[w])                    
                
            # Pad the sequences for missing entries to make them all the same length
            nil_X = zero_vec_pos
            
            pad_length = self.max_sentence_len - len(elem_wordvecs)
            all_X_data.append( ((pad_length)*[nil_X]) + elem_wordvecs)            

        all_X_data = np.array(all_X_data)        
        
        print("UNK WORD COUNT = " + str(len(self.unk_words)))
        print("Found WORDS COUNT = " + str(count))
        print("TOTAL WORDS = " + str(count+len(self.unk_words)))         
        
        print("Done")
        
        return (all_X_data)

# %% [markdown]
# #### Step 3 Create the Neural Network Model in Keras

# %%
# %%writefile Entity_Extractor.py
from keras.preprocessing import sequence
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers.core import Activation
from keras.regularizers import l2
from keras.layers.wrappers import TimeDistributed
from keras.layers.wrappers import Bidirectional
from keras.layers.normalization import BatchNormalization
from keras.layers import Embedding
from keras.layers.core import Dropout
import numpy as np
import pandas as pd
import sys
import keras.backend as K
from sklearn.metrics import confusion_matrix, classification_report

# For reproducibility
np.random.seed(42)

class EntityExtractor:

    def __init__ (self, reader):
        
        self.reader = reader
        self.model = None
#         self.all_X_train, self.all_Y_train, self.all_X_test, self.all_Y_test, self.wordvecs = \
#             reader.get_data()
#         self.train_X = self.all_X_train
#         self.train_Y = self.all_Y_train
        
#         self.test_X = self.all_X_test
#         self.test_Y = self.all_Y_test
        
    def load (self, filepath):
        self.model = load_model(filepath)
        
    def save (self, filepath):
        self.model.save(filepath)

    def print_summary (self):
        print(self.model.summary())        
   
    def train (self, train_file, network_type = 'unidirectional', \
               num_epochs = 1, batch_size = 50, dropout = 0.2, reg_alpha = 0.0, \
               num_hidden_units = 150, num_layers = 1):
        
        self.train_X, self.train_Y = read_and_parse_training_data(train_file)
#         self.train_X = self.all_X_train
#         self.train_Y = self.all_Y_train
        
#         self.test_X = self.all_X_test
#         self.test_Y = self.all_Y_test

        print("Data Shape: ")
        print(train_X.shape)
        print(train_Y.shape)        
        
        dropout = 0.2                
                
        self.model = Sequential()        
        self.model.add(Embedding(self.wordvecs.shape[0], self.wordvecs.shape[1], \
                                 input_length = train_X.shape[1], \
                                 weights = [self.wordvecs], trainable = False))
        
        if network_type == 'unidirectional':
            # uni-directional LSTM
            self.model.add(LSTM(num_hidden_units, return_sequences = True))
        else:
            # bi-directional LSTM
            self.model.add(Bidirectional(LSTM(num_hidden_units, return_sequences = True)))
        
        self.model.add(Dropout(dropout))

        for i in range(1, layers):
            if network_type == 'unidirectional':
                # uni-directional LSTM
                self.model.add(LSTM(num_hidden_units, return_sequences = True))
            else:
                # bi-directional LSTM
                self.model.add(Bidirectional(LSTM(num_hidden_units, return_sequences = True)))
        
            self.model.add(Dropout(dropout))

        self.model.add(TimeDistributed(Dense(train_Y.shape[2], activation='softmax')))

        self.model.compile(loss='categorical_crossentropy', optimizer='adam')
        print(self.model.summary())

        self.model.fit(train_X, train_Y, epochs = num_epochs, batch_size = batch_size)
                
              
    def score_model(self, data_file):
        
        data_X = read_and_parse_unlabeled_data(data_file)
        print("Data Shape: ")        
        print(data_X.shape)
        
        predicted_tags= []
        ind = 0
        for x in data_X:
            tags = self.model.predict(np.array([x]), batch_size=1)[0]
            predicted_tags = self.reader.decode_prediction_sequence(tags)
            ind += 1
            ### To see Progress ###
            if ind%500 == 0: 
                print("Sentence" + str(ind))
        
        predicted_tags = np.array(predicted_tags)
        return (predicted_tags)
    
    def evaluate_model(self, test_file):
        target = open("Pubmed_Output.txt", 'w')
        
        test_X, test_Y = read_and_parse_test_data(test_file)
        
        print("Data Shape: ")        
        print(test_X.shape)
        print(test_Y.shape)
        
        predicted_tags= []
        test_data_tags = []
        ind = 0
        for x,y in zip(test_X, test_Y):
            tags = self.model.predict(np.array([x]), batch_size=1)[0]
            pred_tags = self.reader.decode_prediction_sequence(tags)
            test_tags = self.reader.decode_prediction_sequence(y)
            ind += 1
            ### To see Progress ###
            if ind%500 == 0: 
                print("Sentence" + str(ind))

            pred_tag_wo_none = []
            test_tags_wo_none = []
            
            for index, test_tag in enumerate(test_tags):
                if test_tag != "NONE":
                    if pred_tags[index] == "B-Chemical":
                        pred_tag_wo_none.append("B-Drug")
                    elif pred_tags[index] == "I-Chemical":
                        pred_tag_wo_none.append("I-Drug")
                    elif pred_tags[index] == 'None':
                        pred_tag_wo_none.append('O')
                    else:
                        pred_tag_wo_none.append(pred_tags[index])
                        
                    if test_tag == "B-Chemical":
                        test_tags_wo_none.append("B-Drug")
                    elif test_tag == "I-Chemical":
                        test_tags_wo_none.append("I-Drug")
                    else:                        
                        test_tags_wo_none.append(test_tag)
            
            for wo in pred_tag_wo_none:
                target.write(str(wo))
                target.write("\n")
            target.write("\n")
            
            for i,j in zip(pred_tags, test_tags):
                if i != "NONE" and j != "NONE":
                    test_data_tags.append(j)
                    predicted_tags.append(i)

        target.close()
        
        predicted_tags = np.array(predicted_tags)
        test_data_tags = np.array(test_data_tags)
        print(classification_report(test_data_tags, predicted_tags))

        simple_conf_matrix = confusion_matrix(test_data_tags,predicted_tags)
        all_tags = sorted(list(set(test_data_tags)))
        conf_matrix = pd.DataFrame(columns = all_tags, index = all_tags)
        for x,y in zip(simple_conf_matrix, all_tags):
            conf_matrix[y] = x
        conf_matrix = conf_matrix.transpose()
        
        return conf_matrix

# %% [markdown]
# #### Step 4 Train the network on the prepared data and obtain the predictions on the test set

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hacker\\AppData\\Local\\Temp\\2\\azureml_runs\\NLP_DL_EntityRecognition_1504996997761'

# %%
# from Data_Preparation2 import Data_Preparation2
# from Entity_Extractor import Entity_Extractor
#import cPickle as cp
from keras.models import load_model
import numpy as np

# TRAIN_FILEPATH = "Drugs_and_Diseases//train_out.txt"
# TEST_FILEPATH = "Drugs_and_Diseases//test.txt"
network_type= 'unidirectional'
# network_type= 'bidirectional'
vector_size = 50
num_classes = 7 + 1
seq_length = 613
num_layers = 1
num_epochs = 1

if __name__ == "__main__":
    print("Running on BIO-NLP data\n\n")    

    # Read the data
    print("Initializing data...")
    reader = Data_Preparation(num_classes, seq_length, local_train_file_path, local_test_file_path,\
                              embedding_pickle_file, vector_size)
        
    # Train the model
    print("Training model... epochs = {0}, layers = {1}".format(num_epochs, num_layers))
    model_file_path = os.path.join(home_dir,'Models/lstm_{}_model_lyrs_{}_epchs_{}_vs_{}_ws_{}_mc_{}.h5'.\
                  format(network_type, num_layers, num_epochs, vector_size,window_size, min_count ))
        
    K.clear_session()
    with K.get_session() as sess:        
        K.set_session(sess)
        graphr = K.get_session().graph
        with graphr.as_default():
            entityExtractor = Entity_Extractor(reader)
            entityExtractor.train(network_type = 'unidirectional', epochs=num_epochs, layers=num_layers)    

            #Save the model
            entityExtractor.save(model_file_path)
            
            # Evaluate the model
            print("Evaluating model...")
            confusion_matrix = entityExtractor.evaluate_model()
            print(confusion_matrix)

            print("Done.")     
            
                
        K.clear_session()
        K.set_session(None)
# Out:
# Running on BIO-NLP data
#
#
# Initializing data...
# Loading the W2V model from file C:\dl4nlp\Models/w2vmodel_pubmed_vs_50_ws_5_mc_400.pkl
# Creating the lookup table
# Number of entries in the lookup table = 126855
# embedding size = 50
# Loading the training data from file C:\dl4nlp\Data/Drugs_and_Diseases/train_out.txt
# number of training examples = 15380
# Loading test data from file C:\dl4nlp\Data/Drugs_and_Diseases/test.txt
# number of test examples = 5075
# UNK WORD COUNT = 20711
# Found WORDS COUNT = 399059
# TOTAL WORDS = 419770
# Training model... epochs = 1, layers = 1
# Data Shapes
# (15380, 613)
# (15380, 613, 8)
# (5075, 613)
# (5075, 613, 8)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 613, 50)           6342850
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 613, 150)          120600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 613, 150)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 613, 150)          180600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 613, 150)          0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 613, 8)            1208
# =================================================================
# Total params: 6,645,258
# Trainable params: 302,408
# Non-trainable params: 6,342,850
# _________________________________________________________________
# None
# Epoch 1/1
# 15380/15380 [==============================] - 517s - loss: 0.0934
# Evaluating model...
# Sentence500
# Sentence1000
# Sentence1500
# Sentence2000
# Sentence2500
# Sentence3000
# Sentence3500
# Sentence4000
# Sentence4500
# Sentence5000
# C:\Users\hacker\AppData\local\AmlWorkbench\Python\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#   B-Disease       0.00      0.00      0.00      4049
#      B-Drug       0.71      0.31      0.43      5297
#   I-Disease       0.00      0.00      0.00      2218
#      I-Drug       0.00      0.00      0.00       574
#           O       0.91      1.00      0.95    105355
#
# avg / total       0.85      0.91      0.87    117493
#
#            B-Disease  B-Drug  I-Disease  I-Drug       O
# B-Disease          0      71          0       0    3978
# B-Drug             0    1643          0       0    3654
# I-Disease          0       4          0       0    2214
# I-Drug             0     107          0       0     467
# O                  0     494          0       0  104861
# Done.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-b9be7adfa205> in <module>()
#      43
#      44             print("Done.")
# ---> 45             self.model.save(model_file_path)
#      46
#      47         K.clear_session()
#
# NameError: name 'self' is not defined

# %% [markdown]
# #### Step 5 Generate the output of the model in the correct format for evaluation

# %%
# #save then load the model
# model.save('./outputs/my_model.h5')  # creates a HDF5 file 'my_model.h5'

# # returns a compiled model
# # identical to the previous one
# model_reloaded = load_model('./outputs/my_model.h5')

# # calculate predictions
# predictions = model_reloaded.predict(X)
# print('model reloaded')

model_file_path = os.path.join(home_dir,'./Models/lstm_model_lyrs_{}_epchs_{}_vs_{}_{}.h5'.\
                  format(num_layers, num_epochs, vector_size, network_type))
    
entityExtractor.save(model_file_path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-478f2fb599fa> in <module>()
#      12 model_file_path = os.path.join(home_dir,'./Models/lstm_model_lyrs_{}_epchs_{}_vs_{}_{}.h5'.                  format(num_layers, num_epochs, vector_size, network_type))
#      13
# ---> 14 entityExtractor.save(model_file_path)
#
# <ipython-input-9-7dd9b3c83aa9> in save(self, filepath)
#      39
#      40     def save (self, filepath):
# ---> 41         self.model.save(filepath)
#      42
#      43     def print_summary (self):
#
# ~\AppData\local\AmlWorkbench\Python\lib\site-packages\keras\engine\topology.py in save(self, filepath, overwrite, include_optimizer)
#    2551         """
#    2552         from ..models import save_model
# -> 2553         save_model(self, filepath, overwrite, include_optimizer)
#    2554
#    2555     def save_weights(self, filepath, overwrite=True):
#
# ~\AppData\local\AmlWorkbench\Python\lib\site-packages\keras\models.py in save_model(model, filepath, overwrite, include_optimizer)
#     113         else:
#     114             model_layers = model.layers
# --> 115         topology.save_weights_to_hdf5_group(model_weights_group, model_layers)
#     116
#     117         if include_optimizer and hasattr(model, 'optimizer'):
#
# ~\AppData\local\AmlWorkbench\Python\lib\site-packages\keras\engine\topology.py in save_weights_to_hdf5_group(f, layers)
#    2847         g = f.create_group(layer.name)
#    2848         symbolic_weights = layer.weights
# -> 2849         weight_values = K.batch_get_value(symbolic_weights)
#    2850         weight_names = []
#    2851         for i, (w, val) in enumerate(zip(symbolic_weights, weight_values)):
#
# ~\AppData\local\AmlWorkbench\Python\lib\site-packages\keras\backend\tensorflow_backend.py in batch_get_value(ops)
#    2141     """
#    2142     if ops:
# -> 2143         return get_session().run(ops)
#    2144     else:
#    2145         return []
#
# ~\AppData\local\AmlWorkbench\Python\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\local\AmlWorkbench\Python\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     912     # Check session.
#     913     if self._closed:
# --> 914       raise RuntimeError('Attempted to use a closed Session.')
#     915     if self.graph.version == 0:
#     916       raise RuntimeError('The Session graph is empty.  Add operations to the '
#
# RuntimeError: Attempted to use a closed Session.

# %% [markdown]
# Step 5 Generate the output of the model in the correct format for evaluation

# %%
file1 = open("Pubmed_Output.txt")
file2 = open("Drugs_and_Diseases//test.txt")
target = open("Drugs_and_Diseases//eval2.txt", "w")

list1 = []
list2 = []

for line in file1:
    list1.append(line)
    
for line in file2:
    list2.append(line)
    
for ind, line in enumerate(list2):
    x = line.split("\t")
    if len(x) == 1:
        target.write("\n")
    else:
        target.write(x[0])
        target.write("\t")
        if list1[ind] == "NONE":
            target.write("O")
        else:
            target.write(list1[ind])
    ind += 1
    
file1.close()
file2.close()
target.close()

# %% [markdown]
# #### Evaluate the model predictions on the test data

# %%
# !./Drugs_and_Diseases/evalD_a_D.pl Drugs_and_Diseases/eval2.txt Drugs_and_Diseases/test.txt #with Embedding Layer
# Out:
#                               Biomedical Entity Recognition Performance (Genaral)
#                                                                                          number(recall/precision/f-score)
# +------------------+---------------------------------+---------------------------------+---------------------------------+
# |                  |          complete match         |       right boundary match      |       left boundary match       |
# +------------------+---------------------------------+---------------------------------+---------------------------------+
# |  Disease  (4083) | 2775 (67.96% / 70.36% / 69.14%) | 3211 (78.64% / 81.41% / 80.00%) | 2969 (72.72% / 75.28% / 73.98%) |
# +------------------+---------------------------------+---------------------------------+---------------------------------+
# |   Drug    (5392) | 4237 (78.58% / 75.43% / 76.97%) | 4299 (79.73% / 76.54% / 78.10%) | 4336 (80.42% / 77.19% / 78.77%) |
# +------------------+---------------------------------+---------------------------------+---------------------------------+
# |  [-ALL-]  (9475) | 7012 (74.01% / 73.34% / 73.67%) | 7510 (79.26% / 78.55% / 78.90%) | 7305 (77.10% / 76.40% / 76.75%) |
# +------------------+---------------------------------+---------------------------------+---------------------------------+
